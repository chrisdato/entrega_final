# %% [markdown]
# <a href="https://colab.research.google.com/github/chrisdato/entrega_final/blob/main/AnalisisVG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# %cd '/content/drive/MyDrive/Datasets'
# Out:
# /content/drive/MyDrive/Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('vgsales.csv')
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.tail(5)
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
df.sample(5)
# Out:
#         Rank                                Name Platform    Year      Genre  \
# 12554  12556                         Theresia...       DS  2008.0  Adventure
# 13609  13611             Attack of the Movies 3D     X360  2010.0    Shooter
# 14759  14762  Demon Driver: Time to Burn Rubber!      GBA  2003.0     Racing
# 12399  12401                  The Next BIG Thing       PC  2011.0  Adventure
# 4176    4178               Hot Wheels Velocity X      PS2  2002.0     Racing
#
#                     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 12554        Arc System Works      0.06      0.00       0.0         0.00
# 13609   Majesco Entertainment      0.04      0.00       0.0         0.00
# 14759  Ignition Entertainment      0.02      0.01       0.0         0.00
# 12399  Focus Home Interactive      0.00      0.05       0.0         0.01
# 4176                      THQ      0.23      0.18       0.0         0.06
#
#        Global_Sales
# 12554          0.06
# 13609          0.04
# ...

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df['Name'].value_counts()
# Out:
# Need for Speed: Most Wanted                12
# Ratatouille                                 9
# FIFA 14                                     9
# LEGO Marvel Super Heroes                    9
# Madden NFL 07                               9
#                                            ..
# Ar tonelico Qoga: Knell of Ar Ciel          1
# Galaga: Destination Earth                   1
# Nintendo Presents: Crossword Collection     1
# TrackMania: Build to Race                   1
# Know How 2                                  1
# Name: Name, Length: 11493, dtype: int64

# %%
df['Platform'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df['Genre'].value_counts()
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64

# %%
df['Publisher'].value_counts()
# Out:
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Warp                               1
# New                                1
# Elite                              1
# Evolution Games                    1
# UIG Entertainment                  1
# Name: Publisher, Length: 578, dtype: int64

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.query("Year>=2000 and Year<=2019" )
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 6          7                             New Super Mario Bros.       DS
# 7          8                                          Wii Play      Wii
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
line= df.query("Year>=2000").pivot_table(index='Year', values='EU_Sales', aggfunc='mean')
line.plot(kind='line')

# %%
line=df[df['Year']>=2000].pivot_table(index='Genre', values='EU_Sales', aggfunc='max')
line.plot(kind='line')

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x=df.EU_Sales, y=df.Genre, data=df)

# %%
plt.figure(figsize=(18,8))
sns.boxplot(x=df.Global_Sales, y=df.Genre, data=df)

# %%
plt.hist(x=df['EU_Sales'])
# Out:
# (array([1.6526e+04, 5.1000e+01, 1.2000e+01, 7.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 0.   ,  2.902,  5.804,  8.706, 11.608, 14.51 , 17.412, 20.314,
#         23.216, 26.118, 29.02 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x=df.Global_Sales)
# Out:
# (array([1.6516e+04, 5.9000e+01, 1.3000e+01, 7.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([1.0000e-02, 8.2830e+00, 1.6556e+01, 2.4829e+01, 3.3102e+01,
#         4.1375e+01, 4.9648e+01, 5.7921e+01, 6.6194e+01, 7.4467e+01,
#         8.2740e+01]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x=df.JP_Sales)
# Out:
# (array([1.6364e+04, 1.5400e+02, 4.0000e+01, 2.0000e+01, 1.1000e+01,
#         5.0000e+00, 2.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 0.   ,  1.022,  2.044,  3.066,  4.088,  5.11 ,  6.132,  7.154,
#          8.176,  9.198, 10.22 ]),
#  <a list of 10 Patch objects>)

# %%
df.Other_Sales.hist()

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.plot(kind='line')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
plt.figure(figsize=(8,10))
sns.pairplot(data=df)

# %%
df = df.drop(columns=['Rank','Other_Sales','Year'])

# %%
df.head(5)
# Out:
#                        Name Platform         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii        Sports  Nintendo     41.49
# 1         Super Mario Bros.      NES      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii        Racing  Nintendo     15.85
# 3         Wii Sports Resort      Wii        Sports  Nintendo     15.75
# 4  Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Global_Sales
# 0     29.02      3.77         82.74
# 1      3.58      6.81         40.24
# 2     12.88      3.79         35.82
# 3     11.01      3.28         33.00
# 4      8.89     10.22         31.37

# %%
import missingno as msno
msno.matrix(df)

# %%
df['Publisher'].value_counts().head(1)
# Out:
# Electronic Arts    1351
# Name: Publisher, dtype: int64

# %%
df['Publisher'] = df['Publisher'].fillna('Electronic Arts')
df['Publisher']
# Out:
# 0          Nintendo
# 1          Nintendo
# 2          Nintendo
# 3          Nintendo
# 4          Nintendo
#             ...
# 16593         Kemco
# 16594    Infogrames
# 16595    Activision
# 16596      7G//AMES
# 16597       Wanadoo
# Name: Publisher, Length: 16598, dtype: object

# %%
df['Publisher'].value_counts().head(1)
# Out:
# Electronic Arts    1409
# Name: Publisher, dtype: int64

# %%
msno.matrix(df)

# %%
from sklearn import preprocessing

# %% [markdown]
# Estandarizamos los datos

# %%
dfString = ['NA_Sales', 'EU_Sales','JP_Sales', 'Global_Sales']

# %%
scaler = preprocessing.StandardScaler()

# %%
df[dfString] = scaler.fit_transform(df[dfString])

# %%
print(f' Desviación: {df["EU_Sales"].std()} promedio:{df["EU_Sales"].mean()}')
# Out:
#  Desviación: 1.0000301254726 promedio:7.191901410272132e-17

# %%
plt.hist(df["EU_Sales"])
# Out:
# (array([1.6526e+04, 5.1000e+01, 1.2000e+01, 7.0000e+00, 1.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([-0.29020692,  5.45250675, 11.19522042, 16.93793409, 22.68064776,
#         28.42336143, 34.1660751 , 39.90878877, 45.65150244, 51.39421611,
#         57.13692978]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #¿Era necesario estandarizarlo?

# %% [markdown]
# Normalizamos

# %%
def normalizar(x):
  return (x-x.min())/(x.max()-x.min())

# %%
df[dfString] = normalizar(df[dfString])

# %%
df.head()
# Out:
#                        Name Platform         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii        Sports  Nintendo  1.000000
# 1         Super Mario Bros.      NES      Platform  Nintendo  0.700892
# 2            Mario Kart Wii      Wii        Racing  Nintendo  0.382020
# 3         Wii Sports Resort      Wii        Sports  Nintendo  0.379610
# 4  Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo  0.271632
#
#    EU_Sales  JP_Sales  Global_Sales
# 0  1.000000  0.368885      1.000000
# 1  0.123363  0.666341      0.486281
# 2  0.443832  0.370841      0.432854
# 3  0.379394  0.320939      0.398767
# 4  0.306340  1.000000      0.379064

# %%
df['EU_Sales'].plot(kind='box')

# %% [markdown]
# Transformamos la variable categorica

# %%
df['Name'].unique()[::5] #Borrar name
# Out:
# array(['Wii Sports', 'Tetris', 'Nintendogs', ..., 'Real Rode', 'Breach',
#        'Plushees'], dtype=object)

# %%
df['Platform'].value_counts()[:30] #label encoder
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# Name: Platform, dtype: int64

# %%
print(df['Genre'].value_counts())
print(f'Total generos: {len(df["Genre"].value_counts())}') #Label enconder
# Out:
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Genre, dtype: int64
# Total generos: 12

# %%
len(df['Publisher'].value_counts()) #Label encoder
# Out:
# 578

# %%
df = df.drop(columns=['Name'])
df.head(5)
# Out:
#   Platform         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  Global_Sales
# 0      Wii        Sports  Nintendo  1.000000  1.000000  0.368885      1.000000
# 1      NES      Platform  Nintendo  0.700892  0.123363  0.666341      0.486281
# 2      Wii        Racing  Nintendo  0.382020  0.443832  0.370841      0.432854
# 3      Wii        Sports  Nintendo  0.379610  0.379394  0.320939      0.398767
# 4       GB  Role-Playing  Nintendo  0.271632  0.306340  1.000000      0.379064

# %%
from sklearn.preprocessing import LabelEncoder

# %%
OHE1 = ['Genre','Platform','Publisher']
ohe1 = LabelEncoder()
df[OHE1] = df[OHE1].apply(ohe1.fit_transform)

# %%
df.head(5)
# Out:
#    Platform  Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  Global_Sales
# 0        26     10        359  1.000000  1.000000  0.368885      1.000000
# 1        11      4        359  0.700892  0.123363  0.666341      0.486281
# 2        26      6        359  0.382020  0.443832  0.370841      0.432854
# 3        26     10        359  0.379610  0.379394  0.320939      0.398767
# 4         5      7        359  0.271632  0.306340  1.000000      0.379064

# %%
df.corr()
# Out:
#               Platform     Genre  Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Platform      1.000000  0.029061  -0.012544  0.041536  0.047158 -0.078207
# Genre         0.029061  1.000000  -0.050322  0.017435  0.016481  0.030085
# Publisher    -0.012544 -0.050322   1.000000  0.003377  0.011835  0.051668
# NA_Sales      0.041536  0.017435   0.003377  1.000000  0.767727  0.449787
# EU_Sales      0.047158  0.016481   0.011835  0.767727  1.000000  0.435584
# JP_Sales     -0.078207  0.030085   0.051668  0.449787  0.435584  1.000000
# Global_Sales  0.028213  0.021671   0.017479  0.941047  0.902836  0.611816
#
#               Global_Sales
# Platform          0.028213
# Genre             0.021671
# Publisher         0.017479
# NA_Sales          0.941047
# EU_Sales          0.902836
# JP_Sales          0.611816
# Global_Sales      1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data=df.corr(), cmap='jet')

# %%
#x, y = df.drop('Global_Sales', axis=1), df['Global_Sales']
x, y =  df['EU_Sales'], df['Global_Sales']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Implementación modelo

# %% [markdown]
# ##Regresiones

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x.values.reshape(-1,1), y, random_state=11)

# %%
regresion = LinearRegression()

# %%
regresion.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
predict = regresion.predict(X_test)
real = Y_test

# %%
for p,r in zip(prediccion[:30], real[:30]):
  print(f'Prediccion: {p:.2f} vs real: {r:.2f}')
# Out:
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.01
# Prediccion: 0.01 vs real: 0.01
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.01
# Prediccion: 0.01 vs real: 0.02
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.01
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.00
# Prediccion: 0.01 vs real: 0.01
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.00
# Prediccion: 0.00 vs real: 0.01
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.02
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.00 vs real: 0.00
# Prediccion: 0.01 vs real: 0.01
# Prediccion: 0.01 vs real: 0.03
# Prediccion: 0.01 vs real: 0.00

# %%
regresion.coef_
# Out:
# array([0.96702834])

# %%
regresion.intercept_
# Out:
# 0.0014788814154754245

# %%
prediccion = (lambda x: regresion.coef_*x+regresion.intercept_)

# %%
prediccion(5000)
# Out:
# array([4835.14318688])

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
print(f'R2 es: {r2_score(y_true=real, y_pred=predict)}')
print(f'MSE es {mean_squared_error(y_true=real, y_pred=predict)}')
# Out:
# R2 es: 0.9124371514937129
# MSE es 4.5815320099477545e-05

# %%
x, y = df.drop('Global_Sales', axis=1), df['Global_Sales']

# %%
x_train, x_test, y_train, y_test= train_test_split(x,y, random_state=80)

# %%
import xgboost as xg

# %%
xgb_r = xg.XGBRegressor(objetive='reg:squarederror', n_estimators=100, seed=42, max_depth=10, eta=0.01, subsample=0.7, colsample_bytree=0.8)
xgb_r.fit(x_train, y_train)
# Out:
# [01:10:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(colsample_bytree=0.8, eta=0.01, max_depth=10,
#              objetive='reg:squarederror', seed=42, subsample=0.7)

# %%
y_pred = xgb_r.predict(x_test)

# %%
y_pred
# Out:
# array([7.5765252e-03, 1.2903631e-02, 9.8407269e-05, ..., 2.6876926e-02,
#        7.4306130e-04, 6.4376891e-03], dtype=float32)

# %%
print(f'R2 es: {r2_score(y_true=y_test, y_pred=y_pred)}')
# Out:
# R2 es: 0.9728371900458184
